# %%
import h5py
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
mask = np.load(r"C:\Users\DU\aman_fastmri\Data\mask_4x_320_random.npy")  # Shape: (1, 320, 320)
print("og shape:", mask.shape)

# # Use np.tile to reshape it to (1, 320, 320, 1)
# # var_sampling_mask = np.tile(var_sampling_mask[..., np.newaxis], (1, 1, 1, 1))  # Final shape: (1, 320, 320, 1)
# mask = np.tile(mask, (1, 320, 1, 2))  # tile height=320 times

# # Confirm final shape
# print("New shape:", mask.shape) 
# mask_for_plot = np.squeeze(mask[...,0])  # Shape: (320, 320)

# # Plot
# plt.figure(figsize=(5, 5))
# plt.imshow(mask_for_plot, cmap='gray')
# plt.title("Tiled Sampling Mask (320x320)")
# plt.axis('off')
# plt.show()
# Out:
# og shape: (1, 1, 320, 1)

# %%
import h5py
import numpy as np
import tensorflow as tf

class MRISliceGenerator(tf.keras.utils.Sequence):
    def __init__(self, file_list, batch_size=4, shuffle=True, mask=None):
        self.file_list = file_list
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.mask = mask  # Shape: (1, 320, 320, 2)
        self.slice_index_map = []
        self._build_index()

    def _build_index(self):
        for file_idx, file_path in enumerate(self.file_list):
            with h5py.File(file_path, 'r') as f:
                num_slices = f['image_under'].shape[0]
                for slice_idx in range(num_slices):
                    self.slice_index_map.append((file_idx, slice_idx))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.slice_index_map) / self.batch_size))

    def __getitem__(self, index):
        batch_map = self.slice_index_map[index * self.batch_size:(index + 1) * self.batch_size]

        input_img_batch = []
        target_img_batch = []
        input_kspace_batch = []

        for file_idx, slice_idx in batch_map:
            with h5py.File(self.file_list[file_idx], 'r') as f:
                input_img = f['image_under'][slice_idx]       # shape: [H, W, 2]
                target_img = f['image_full'][slice_idx]       # shape: [H, W, 2]
                input_kspace = f['kspace_under'][slice_idx]   # shape: [H, W, 2]

                input_img_batch.append(input_img)
                target_img_batch.append(target_img)
                input_kspace_batch.append(input_kspace)

        x_img = np.stack(input_img_batch, axis=0)
        x_kspace = np.stack(input_kspace_batch, axis=0)
        y_batch = np.stack(target_img_batch, axis=0)

        # if self.mask is not None:
        #     actual_batch_size = len(x_img)
        #     if self.mask.shape == (1, 320, 320, 2):
        #         mask_batch = np.tile(self.mask, (actual_batch_size, 1, 1, 1))
        #     else:
        #         raise ValueError("Mask must have shape (1, 320, 320, 2)")
        #     return [x_img, mask_batch, x_kspace], y_batch
        # else:
        #     return [x_img, x_kspace], y_batch
        return x_img, y_batch

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.slice_index_map)

# %%
train_folder = r"D:\fastmri_singlecoil_FSSCAN\train_norm"
val_folder = r"D:\fastmri_singlecoil_FSSCAN\val_norm"

# %%
import h5py
import numpy as np
import glob
import os
kspace_files_list_train = sorted(glob.glob(os.path.join(train_folder, "*.h5")))
kspace_files_list_val = sorted(glob.glob(os.path.join(val_folder, "*.h5")))

# half_train = 20
# half_val = 10
half_train = len(kspace_files_list_train) 
half_val = len(kspace_files_list_val) 
# print("half_train",half_train)
# print("half_val",half_val)
kspace_files_list_train = kspace_files_list_train[:half_train]
kspace_files_list_val = kspace_files_list_val[:half_val]

# Create generators
# train_gen = MRISliceGeneratorMag(kspace_files_list_train,batch_size=4, shuffle=True,mask=mask)
# val_gen = MRISliceGeneratorMag(kspace_files_list_val, batch_size=4, shuffle=False,mask=mask)
train_gen = MRISliceGenerator(kspace_files_list_train,batch_size=8, shuffle=True)
val_gen = MRISliceGenerator(kspace_files_list_val, batch_size=4, shuffle=False)

print(len(train_gen))  
print(len(val_gen))
# Out:
# 4338
# 1784

# %%
# %run ./DCR-Unet.ipynb
#SOTA_paper_2_DCRCNN/SOTA_paper_2_DCRCNN-20251226T060810Z-1-001/SOTA_paper_2_DCRCNN/DCR-Unet.ipynb
# Out:
# Model: "DCR_UNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 320, 320, 2  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 320, 320, 32  96          ['input_1[0][0]']
#                                 )
#
#  p_re_lu (PReLU)                (None, 320, 320, 32  32          ['conv2d[0][0]']
#                                 )
#
#  dcr_block_u_net (DCRBlockUNet)  (None, 320, 320, 32  31136      ['p_re_lu[0][0]']
#                                 )
#
#  dcr_block_u_net_1 (DCRBlockUNe  (None, 320, 320, 32  31136      ['dcr_block_u_net[0][0]']
#  t)                             )
#
#  max_pooling2d (MaxPooling2D)   (None, 160, 160, 32  0           ['dcr_block_u_net_1[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 160, 160, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  dcr_block_u_net_2 (DCRBlockUNe  (None, 160, 160, 64  124224     ['conv2d_9[0][0]']
#  t)                             )
#
#  dcr_block_u_net_3 (DCRBlockUNe  (None, 160, 160, 64  124224     ['dcr_block_u_net_2[0][0]']
#  t)                             )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 80, 80, 64)  0           ['dcr_block_u_net_3[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 80, 80, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  dcr_block_u_net_4 (DCRBlockUNe  (None, 80, 80, 128)  496256     ['conv2d_18[0][0]']
#  t)
#
#  dcr_block_u_net_5 (DCRBlockUNe  (None, 80, 80, 128)  496256     ['dcr_block_u_net_4[0][0]']
#  t)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 40, 40, 128)  0          ['dcr_block_u_net_5[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 40, 40, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  dcr_block_u_net_6 (DCRBlockUNe  (None, 40, 40, 256)  1983744    ['conv2d_27[0][0]']
#  t)
#
#  dcr_block_u_net_7 (DCRBlockUNe  (None, 40, 40, 256)  1983744    ['dcr_block_u_net_6[0][0]']
#  t)
#
#  up_sampling2d (UpSampling2D)   (None, 80, 80, 256)  0           ['dcr_block_u_net_7[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 80, 80, 128)  295040      ['up_sampling2d[0][0]']
#
#  concatenate (Concatenate)      (None, 80, 80, 256)  0           ['conv2d_36[0][0]',
#                                                                   'dcr_block_u_net_5[0][0]']
#
#  dcr_block_u_net_8 (DCRBlockUNe  (None, 80, 80, 256)  1983744    ['concatenate[0][0]']
#  t)
#
#  dcr_block_u_net_9 (DCRBlockUNe  (None, 80, 80, 256)  1983744    ['dcr_block_u_net_8[0][0]']
#  t)
#
#  up_sampling2d_1 (UpSampling2D)  (None, 160, 160, 25  0          ['dcr_block_u_net_9[0][0]']
#                                 6)
#
#  conv2d_45 (Conv2D)             (None, 160, 160, 64  147520      ['up_sampling2d_1[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 160, 160, 12  0           ['conv2d_45[0][0]',
#                                 8)                                'dcr_block_u_net_3[0][0]']
#
#  dcr_block_u_net_10 (DCRBlockUN  (None, 160, 160, 12  496256     ['concatenate_1[0][0]']
#  et)                            8)
#
#  dcr_block_u_net_11 (DCRBlockUN  (None, 160, 160, 12  496256     ['dcr_block_u_net_10[0][0]']
#  et)                            8)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 320, 320, 12  0          ['dcr_block_u_net_11[0][0]']
#                                 8)
#
#  conv2d_54 (Conv2D)             (None, 320, 320, 32  36896       ['up_sampling2d_2[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 320, 320, 64  0           ['conv2d_54[0][0]',
#                                 )                                 'dcr_block_u_net_1[0][0]']
#
#  dcr_block_u_net_12 (DCRBlockUN  (None, 320, 320, 64  124224     ['concatenate_2[0][0]']
#  et)                            )
#
#  dcr_block_u_net_13 (DCRBlockUN  (None, 320, 320, 64  124224     ['dcr_block_u_net_12[0][0]']
#  et)                            )
#
#  conv2d_63 (Conv2D)             (None, 320, 320, 2)  130         ['dcr_block_u_net_13[0][0]']
#
#  add (Add)                      (None, 320, 320, 2)  0           ['conv2d_63[0][0]',
#                                                                   'input_1[0][0]']
#
# ==================================================================================================
# Total params: 11,346,402
# Trainable params: 11,346,402
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# ============================================================
# Directory Setup
# ============================================================
save_dir = "./SavedModels_DCUNET_full_2"
os.makedirs(save_dir, exist_ok=True)

# ============================================================
# Configuration
# ============================================================
H, W = 320, 320
EPOCHS = 50
LEARNING_RATE = 1e-4

# TensorFlow checkpoint paths (NO .h5)
INIT_CKPT  = os.path.join(save_dir, "init_ckpt")
BEST_CKPT  = os.path.join(save_dir, "best_ckpt")
FINAL_CKPT = os.path.join(save_dir, "final_ckpt")

print("=" * 60)
print("🔧 TRAINING CONFIGURATION")
print("=" * 60)
print(f" Save Directory:       {save_dir}")
print(f" Model Dimensions:     {H}x{W}")
print(f" Epochs:               {EPOCHS}")
print(f" Learning Rate:        {LEARNING_RATE}")
print(f" Init Checkpoint:      {INIT_CKPT}")
print(f" Best Checkpoint:      {BEST_CKPT}")
print(f" Final Checkpoint:     {FINAL_CKPT}")
print("=" * 60)

# ============================================================
# Model Setup
# ============================================================
# model = build_dcr_cnn(
#     input_shape=(320, 320, 1),
#     num_dcr_blocks=10,   # or 3 / 8
#     num_features=64,
#     growth_rate=32
# )

model = build_dcr_unet(input_shape=(320, 320, 2))
# ============================================================
# Optimizer & Compile
# ============================================================
optimizer = Adam(learning_rate=LEARNING_RATE)
model.compile(optimizer=optimizer, loss="mse")

# ============================================================
# Load Initial Weights (Optional Resume)
# ============================================================
if tf.train.latest_checkpoint(save_dir):
    model.load_weights(tf.train.latest_checkpoint(save_dir))
    print("✅ Loaded latest checkpoint")
else:
    print("ℹ️ No checkpoint found. Training from scratch.")

# ============================================================
# Callbacks
# ============================================================
checkpoint_cb = ModelCheckpoint(
    filepath=BEST_CKPT,
    monitor="val_loss",
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

earlystop_cb = EarlyStopping(
    monitor="val_loss",
    patience=20,
    restore_best_weights=True,
    verbose=1
)

reduce_lr_cb = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.5,
    patience=10,
    min_lr=1e-7,
    verbose=1
)

callbacks = [checkpoint_cb, earlystop_cb, reduce_lr_cb]

# ============================================================
# Training
# ============================================================
print("\n🚀 STARTING TRAINING...")
print("=" * 60)

history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1
)

print("\n✅ TRAINING COMPLETED")

# ============================================================
# Save Final Weights
# ============================================================
model.save_weights(FINAL_CKPT)
print(f"✅ Final weights saved to {FINAL_CKPT}")

# ============================================================
# Training Analysis
# ============================================================
if history:
    print("\n📊 TRAINING ANALYSIS")
    print("=" * 60)
    best_epoch = np.argmin(history.history["val_loss"]) + 1
    print(f" Best Epoch: {best_epoch}")
    print(f" Best Val Loss: {np.min(history.history['val_loss']):.6f}")

# ============================================================
# Plot Training Curves
# ============================================================
# Out:
# ============================================================
# 🔧 TRAINING CONFIGURATION
# ============================================================
#  Save Directory:       ./SavedModels_DCUNET_full_2
#  Model Dimensions:     320x320
#  Epochs:               50
#  Learning Rate:        0.0001
#  Init Checkpoint:      ./SavedModels_DCUNET_full_2\init_ckpt
#  Best Checkpoint:      ./SavedModels_DCUNET_full_2\best_ckpt
#  Final Checkpoint:     ./SavedModels_DCUNET_full_2\final_ckpt
# ============================================================
# ℹ️ No checkpoint found. Training from scratch.
#
# 🚀 STARTING TRAINING...
# ============================================================
# Epoch 1/50
# 4338/4338 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 1: val_loss improved from inf to 0.00082, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3290s 754ms/step - loss: 0.0013 - val_loss: 8.2339e-04 - lr: 1.0000e-04
# Epoch 2/50
# 4338/4338 [==============================] - ETA: 0s - loss: 7.3991e-04
# Epoch 2: val_loss improved from 0.00082 to 0.00079, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3269s 754ms/step - loss: 7.3991e-04 - val_loss: 7.8744e-04 - lr: 1.0000e-04
# Epoch 3/50
# 4338/4338 [==============================] - ETA: 0s - loss: 7.1388e-04
# Epoch 3: val_loss improved from 0.00079 to 0.00077, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3267s 753ms/step - loss: 7.1388e-04 - val_loss: 7.6929e-04 - lr: 1.0000e-04
# Epoch 4/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.9654e-04
# Epoch 4: val_loss improved from 0.00077 to 0.00076, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3267s 753ms/step - loss: 6.9654e-04 - val_loss: 7.5607e-04 - lr: 1.0000e-04
# Epoch 5/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.8390e-04
# Epoch 5: val_loss improved from 0.00076 to 0.00075, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3266s 753ms/step - loss: 6.8390e-04 - val_loss: 7.4611e-04 - lr: 1.0000e-04
# Epoch 6/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.7602e-04
# Epoch 6: val_loss improved from 0.00075 to 0.00074, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3266s 753ms/step - loss: 6.7602e-04 - val_loss: 7.4006e-04 - lr: 1.0000e-04
# Epoch 7/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.7087e-04
# Epoch 7: val_loss improved from 0.00074 to 0.00074, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3266s 753ms/step - loss: 6.7087e-04 - val_loss: 7.3566e-04 - lr: 1.0000e-04
# Epoch 8/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.6760e-04
# Epoch 8: val_loss improved from 0.00074 to 0.00073, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3266s 753ms/step - loss: 6.6760e-04 - val_loss: 7.3279e-04 - lr: 1.0000e-04
# Epoch 9/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.6431e-04
# Epoch 9: val_loss improved from 0.00073 to 0.00073, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3264s 753ms/step - loss: 6.6431e-04 - val_loss: 7.3161e-04 - lr: 1.0000e-04
# Epoch 10/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.6215e-04
# Epoch 10: val_loss improved from 0.00073 to 0.00073, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3264s 752ms/step - loss: 6.6215e-04 - val_loss: 7.3042e-04 - lr: 1.0000e-04
# Epoch 11/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.6004e-04
# Epoch 11: val_loss improved from 0.00073 to 0.00073, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 4338/4338 [==============================] - 3264s 752ms/step - loss: 6.6004e-04 - val_loss: 7.2786e-04 - lr: 1.0000e-04
# Epoch 12/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.5653e-04
# Epoch 12: val_loss improved from 0.00073 to 0.00073, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3274s 755ms/step - loss: 6.5653e-04 - val_loss: 7.2557e-04 - lr: 5.0000e-05
# Epoch 13/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.5558e-04
# Epoch 13: val_loss improved from 0.00073 to 0.00073, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3278s 756ms/step - loss: 6.5558e-04 - val_loss: 7.2526e-04 - lr: 5.0000e-05
# Epoch 14/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.5472e-04
# Epoch 14: val_loss improved from 0.00073 to 0.00072, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3271s 754ms/step - loss: 6.5472e-04 - val_loss: 7.2451e-04 - lr: 5.0000e-05
# Epoch 15/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.5395e-04
# Epoch 15: val_loss improved from 0.00072 to 0.00072, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3270s 754ms/step - loss: 6.5395e-04 - val_loss: 7.2417e-04 - lr: 5.0000e-05
# Epoch 16/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.5324e-04
# Epoch 16: val_loss improved from 0.00072 to 0.00072, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3275s 755ms/step - loss: 6.5324e-04 - val_loss: 7.2409e-04 - lr: 5.0000e-05
# Epoch 17/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.5258e-04
# Epoch 17: val_loss improved from 0.00072 to 0.00072, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3267s 753ms/step - loss: 6.5258e-04 - val_loss: 7.2345e-04 - lr: 5.0000e-05
# Epoch 18/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.5195e-04
# Epoch 18: val_loss improved from 0.00072 to 0.00072, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3268s 753ms/step - loss: 6.5195e-04 - val_loss: 7.2293e-04 - lr: 5.0000e-05
# Epoch 19/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.5137e-04
# Epoch 19: val_loss did not improve from 0.00072
# 4338/4338 [==============================] - 3269s 753ms/step - loss: 6.5137e-04 - val_loss: 7.2325e-04 - lr: 5.0000e-05
# Epoch 20/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.5079e-04
# Epoch 20: val_loss improved from 0.00072 to 0.00072, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3272s 754ms/step - loss: 6.5079e-04 - val_loss: 7.2258e-04 - lr: 5.0000e-05
# Epoch 21/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.5024e-04
# Epoch 21: val_loss did not improve from 0.00072
# 4338/4338 [==============================] - 3284s 757ms/step - loss: 6.5024e-04 - val_loss: 7.2289e-04 - lr: 5.0000e-05
# Epoch 22/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.4973e-04
# Epoch 22: val_loss improved from 0.00072 to 0.00072, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3279s 756ms/step - loss: 6.4973e-04 - val_loss: 7.2225e-04 - lr: 5.0000e-05
# Epoch 23/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.4923e-04
# Epoch 23: val_loss improved from 0.00072 to 0.00072, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3342s 770ms/step - loss: 6.4923e-04 - val_loss: 7.2217e-04 - lr: 5.0000e-05
# Epoch 24/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.4873e-04
# Epoch 24: val_loss improved from 0.00072 to 0.00072, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3303s 761ms/step - loss: 6.4873e-04 - val_loss: 7.2204e-04 - lr: 5.0000e-05
# Epoch 25/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.4826e-04
# Epoch 25: val_loss improved from 0.00072 to 0.00072, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3329s 767ms/step - loss: 6.4826e-04 - val_loss: 7.2192e-04 - lr: 5.0000e-05
# Epoch 26/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.4784e-04
# Epoch 26: val_loss improved from 0.00072 to 0.00072, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3664s 845ms/step - loss: 6.4784e-04 - val_loss: 7.2166e-04 - lr: 5.0000e-05
# Epoch 27/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.4744e-04
# Epoch 27: val_loss did not improve from 0.00072
# 4338/4338 [==============================] - 3514s 810ms/step - loss: 6.4744e-04 - val_loss: 7.2166e-04 - lr: 5.0000e-05
# Epoch 28/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.4700e-04
# Epoch 28: val_loss improved from 0.00072 to 0.00072, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 4338/4338 [==============================] - 3352s 773ms/step - loss: 6.4700e-04 - val_loss: 7.2125e-04 - lr: 5.0000e-05
# Epoch 29/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.4556e-04
# Epoch 29: val_loss improved from 0.00072 to 0.00072, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3400s 784ms/step - loss: 6.4556e-04 - val_loss: 7.2100e-04 - lr: 2.5000e-05
# Epoch 30/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.4525e-04
# Epoch 30: val_loss did not improve from 0.00072
# 4338/4338 [==============================] - 3287s 758ms/step - loss: 6.4525e-04 - val_loss: 7.2109e-04 - lr: 2.5000e-05
# Epoch 31/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.4501e-04
# Epoch 31: val_loss improved from 0.00072 to 0.00072, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3288s 758ms/step - loss: 6.4501e-04 - val_loss: 7.2099e-04 - lr: 2.5000e-05
# Epoch 32/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.4478e-04
# Epoch 32: val_loss did not improve from 0.00072
# 4338/4338 [==============================] - 3287s 758ms/step - loss: 6.4478e-04 - val_loss: 7.2107e-04 - lr: 2.5000e-05
# Epoch 33/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.4456e-04
# Epoch 33: val_loss did not improve from 0.00072
# 4338/4338 [==============================] - 3286s 758ms/step - loss: 6.4456e-04 - val_loss: 7.2104e-04 - lr: 2.5000e-05
# Epoch 34/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.4435e-04
# Epoch 34: val_loss did not improve from 0.00072
# 4338/4338 [==============================] - 3286s 758ms/step - loss: 6.4435e-04 - val_loss: 7.2099e-04 - lr: 2.5000e-05
# Epoch 35/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.4413e-04
# Epoch 35: val_loss did not improve from 0.00072
# 4338/4338 [==============================] - 3287s 758ms/step - loss: 6.4413e-04 - val_loss: 7.2111e-04 - lr: 2.5000e-05
# Epoch 36/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.4394e-04
# Epoch 36: val_loss improved from 0.00072 to 0.00072, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3288s 758ms/step - loss: 6.4394e-04 - val_loss: 7.2094e-04 - lr: 2.5000e-05
# Epoch 37/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.4375e-04
# Epoch 37: val_loss did not improve from 0.00072
# 4338/4338 [==============================] - 3287s 758ms/step - loss: 6.4375e-04 - val_loss: 7.2103e-04 - lr: 2.5000e-05
# Epoch 38/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.4355e-04
# Epoch 38: val_loss did not improve from 0.00072
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 4338/4338 [==============================] - 3290s 758ms/step - loss: 6.4355e-04 - val_loss: 7.2111e-04 - lr: 2.5000e-05
# Epoch 39/50
# 4338/4338 [==============================] - ETA: 0s - loss: 6.4281e-04
# Epoch 39: val_loss improved from 0.00072 to 0.00072, saving model to ./SavedModels_DCUNET_full_2\best_ckpt
# 4338/4338 [==============================] - 3341s 770ms/step - loss: 6.4281e-04 - val_loss: 7.2087e-04 - lr: 1.2500e-05
# Epoch 40/50
# 4324/4338 [============================>.] - ETA: 9s - loss: 6.4287e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 99
#      96 print("\n🚀 STARTING TRAINING...")
#      97 print("=" * 60)
# ---> 99 history = model.fit(
#     100     train_gen,
#     101     validation_data=val_gen,
#     102     epochs=EPOCHS,
#     103     callbacks=callbacks,
#     104     verbose=1
#     105 )
#     107 print("\n✅ TRAINING COMPLETED")
#     109 # ============================================================
#     110 # Save Final Weights
#     111 # ============================================================
#
# File ~\anaconda3\envs\WNet\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\WNet\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File ~\anaconda3\envs\WNet\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\envs\WNet\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\envs\WNet\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~\anaconda3\envs\WNet\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\anaconda3\envs\WNet\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\envs\WNet\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File ~\anaconda3\envs\WNet\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:
